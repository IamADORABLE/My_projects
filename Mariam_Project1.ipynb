# %% [markdown]
# <a href="https://colab.research.google.com/github/IamADORABLE/My_projects/blob/main/Mariam_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Basic Calculator
""" This Python calculator allows users to perform operations like addition, subtraction, multiplication, division, modulus, exponentiation, and square root.
It repeatedly prompts the user for input and performs calculations until the user chooses to exit.
It handles invalid input and division by zero gracefully, ensuring a smooth user experience
"""


import math

# Function to add two numbers
def add(a, b):
    return a + b

# Function to subtract second number from first
def subtract(a, b):
    return a - b

# Function to multiply two numbers
def multiply(a, b):
    return a * b

# Function to divide first number by second
def divide(a, b):
    if b != 0:
        return a / b
    else:
        return "Error: Division by zero"

# Function for modulus
def modulus(a, b):
    return a % b

# Function for exponentiation (x^y)
def exponent(a, b):
    return a ** b

# Function for square root
def square_root(a):
    if a >= 0:
        return math.sqrt(a)
    else:
        return "Error: Cannot find square root of negative number"

# Calculator loop
while True:
    print("\n====== Basic Python Calculator ======")
    print("Select operation:")
    print("A. Add (a + b)")
    print("B. Subtract (a - b)")
    print("C. Multiply (a * b)")
    print("D. Divide (a / b)")
    print("E. Modulus (a % b)")
    print("F. Exponentiation (a ^ b)")
    print("G. Square Root (√a)")
    print("H. Exit")

    choice = input("Enter your choice (A-H): ")

    if choice == 'H':
        print("\nThank you for using the calculator. Goodbye!")
        break

    if choice == 'G':
        try:
            num = float(input("Enter number: "))
            result = square_root(num)
            print(f"√{num} = {result}")
        except ValueError:
            print("Invalid input! Please enter a numeric value.")
        continue

    try:
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))
    except ValueError:
        print("Invalid input! Please enter numeric values.")
        continue

    # Perform calculation
    if choice == 'A':
        result = add(num1, num2)
        print(f"{num1} + {num2} = {result}")
    elif choice == 'B':
        result = subtract(num1, num2)
        print(f"{num1} - {num2} = {result}")
    elif choice == 'C':
        result = multiply(num1, num2)
        print(f"{num1} * {num2} = {result}")
    elif choice == 'D':
        result = divide(num1, num2)
        print(f"{num1} / {num2} = {result}")
    elif choice == 'E':
        result = modulus(num1, num2)
        print(f"{num1} % {num2} = {result}")
    elif choice == 'F':4
        result = exponent(num1, num2)
        print(f"{num1} ^ {num2} = {result}")
    else:
        print("Invalid choice. Please enter a number from 1 to 8.")
# Out:
# ====== Basic Python Calculator ======
# Select operation:
# A. Add (a + b)
# B. Subtract (a - b)
# C. Multiply (a * b)
# D. Divide (a / b)
# E. Modulus (a % b)
# F. Exponentiation (a ^ b)
# G. Square Root (√a)
# H. Exit
# Enter your choice (A-H): A
# Enter first number: 15
# Enter second number: 25
# 15.0 + 25.0 = 40.0
#
# ====== Basic Python Calculator ======
# Select operation:
# A. Add (a + b)
# B. Subtract (a - b)
# C. Multiply (a * b)
# D. Divide (a / b)
# E. Modulus (a % b)
# F. Exponentiation (a ^ b)
# G. Square Root (√a)
# H. Exit
# Enter your choice (A-H): B
# Enter first number: 12
# Enter second number: 3
# 12.0 - 3.0 = 9.0
#
# ====== Basic Python Calculator ======
# Select operation:
# A. Add (a + b)
# B. Subtract (a - b)
# C. Multiply (a * b)
# D. Divide (a / b)
# E. Modulus (a % b)
# F. Exponentiation (a ^ b)
# G. Square Root (√a)
# H. Exit
# Enter your choice (A-H): C
# Enter first number: 10
# Enter second number: 4
# 10.0 * 4.0 = 40.0
#
# ...
